# %% [markdown]
# # Experiment 9
# ### Name- Shreya
# ### PRN- 25070123159
# ### Batch- A3
# ### Title- Study of Pandas Library

# %%
# Introduction to Pandas
# Pandas: Panel Data
''' Used for Structured Data, EDA, Data Cleaning '''
# Out:
# ' Used for Structured Data, EDA, Data Cleaning '

# %%
import pandas as pd
s = pd.Series([10,20,30,40])
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
# Create a DataFrame
data= {"Name":["A","B","C"], "Marks":[85,90,78]}
df= pd.DataFrame(data)
df
# Out:
#   Name  Marks
# 0    A     85
# 1    B     90
# 2    C     78

# %%
df.head() # prints first 5 entries
# Out:
#   Name  Marks
# 0    A     85
# 1    B     90
# 2    C     78

# %%
# Find the Structure of the DataFrame
df.shape
# Out:
# (3, 2)

# %%
df.ndim  #gives number of columms
# Out:
# 2

# %%
df.size  #total values in the dataset
# Out:
# 6

# %%
# Display Column Names
df.columns
# Out:
# Index(['Name', 'Marks'], dtype='object')

# %%
# Check Data Types in each columns
df.dtypes
# Out:
# Name     object
# Marks     int64
# dtype: object

# %%
# Access Individual Column
df["Name"]
# Out:
# 0    A
# 1    B
# 2    C
# Name: Name, dtype: object

# %%
df["Marks"]
# Out:
# 0    85
# 1    90
# 2    78
# Name: Marks, dtype: int64

# %%
# Access Specific Row
df.loc[2]
# Out:
# Name      C
# Marks    78
# Name: 2, dtype: object

# %%
# Add a new column
''' If marks between 80-90 then First class
If marks>90 then Distinction
If marks>80-90 then second class '''
df["Grade"]=["First Class","Distinction","Second Class"]
df
# Out:
#   Name  Marks         Grade
# 0    A     85   First Class
# 1    B     90   Distinction
# 2    C     78  Second Class

# %%
# Update Data in DataFrame
# Change marks of student A to 88
df.loc[0,"Marks"]= 88
df
# Out:
#   Name  Marks
# 0    A     88
# 1    B     90
# 2    C     78

# %%
# Delete a column
df.drop("Grade",axis=1, inplace=True)  # axis=1 is for columns
df
# Out:
#   Name  Marks
# 0    A     85
# 1    B     90
# 2    C     78

# %%
# Perform Basic Statistical Analysis
mean1=df["Marks"].mean()
mean1
# Out:
# np.float64(84.33333333333333)

# %%
min1=df["Marks"].min()
min1
# Out:
# 78

# %%
max=df["Marks"].max()
max
# Out:
# 90

# %%
# Apply Condition (Fitering)
# Display students scoring more than 80
df[df["Marks"]>80]
# Out:
#   Name  Marks
# 0    A     85
# 1    B     90

# %%
import pandas as pd
import numpy as np
df1=pd.DataFrame({'C1':[11,21,np.nan],'C2':[15,np.nan,np.nan],'C3':[10,20,30]})
df1
# Out:
#      C1    C2  C3
# 0  11.0  15.0  10
# 1  21.0   NaN  20
# 2   NaN   NaN  30

# %%
df1.isna () #Boolean function
# Out:
#       C1     C2     C3
# 0  False  False  False
# 1  False   True  False
# 2   True   True  False

# %%
df1.notna ()
# Out:
#       C1     C2    C3
# 0   True   True  True
# 1   True  False  True
# 2  False  False  True

# %%
df1.isna().sum()
# Out:
# C1    1
# C2    2
# C3    0
# dtype: int64

# %%
df1.dropna () # drops the rows which has nan
# Out:
#      C1    C2  C3
# 0  11.0  15.0  10
