# %% [markdown]
# # Experiment 6
# ### Name- Shreya
# ### PRN- 25070123159
# ### Batch- A3
# ### Title- To Study Conditional Statements in Python

# %%
# to check whether a number is positive or negative
num=int(input("enter a number:"))
if num>0:
  print("number is positive")
else:
  print("number is negative")
# Out:
# enter a number:3
# number is positive

# %%
# to check whether a number is positive or negative or zero
num=int(input("enter a number: "))
if num>0:
  print("number is posiitve")
elif num<0:
    print("number is negative")
else:
    print("number is zero")
# Out:
# enter a number: -2
# number is negative

# %%
# to check whether a number is odd or even
num=int(input("enter a number: "))
if num%2==0:
  print("number is even")
else:
  print("number is odd")
# Out:
# enter a number: 8
# number is even

# %%
# to find the greater number amongst two numbers
a=int(input("enter first number: "))
b=int(input("enter second number: "))
if a>b:
  print("a is greater than b")
elif a<b:
  print("b is greater than a")
else:
  print("both are equal")
# Out:
# enter first number: 3
# enter second number: 4
# b is greater than a

# %%
# to find largest of three numbers
a=int(input("enter first number:"))
b=int(input("enter second number:"))
c=int(input("enter third number:"))
if a>b and a>c:
  print("largest:",a)
elif b>a and b>c:
    print("largest:",b)
else:
      print("largest:",c)
# Out:
# enter first number:1
# enter second number:2
# enter third number:3
# largest: 3

# %%
# get input from user for 5 subjects and find average and calculate grade using if-elif-else
a=int(input("enter marks of first subject:"))
b=int(input("enter marks of second subject:"))
c=int(input("enter marks of third subject:"))
d=int(input("enter marks of fourth subject:"))
e=int(input("enter marks of fifth subject:"))
avg_marks=(a+b+c+d+e)/5
print("average marks:",avg_marks)
if avg_marks>=90:
  print("grade: A")
elif avg_marks>=80:
  print("grade: B")
elif avg_marks>=70:
  print("grade: C")
else:
  print("fail")
# Out:
# enter marks of first subject:70
# enter marks of second subject:90
# enter marks of third subject:90
# enter marks of fourth subject:80
# enter marks of fifth subject:90
# average marks: 84.0
# grade: B

# %%
 # to check whether a year is a leap year or not
year= int(input("enter a year: "))
if (year % 4==0 and year%100!=0) or (year%400==0):
  print("its a leap year")
else:
  print("its not a leap year")
# Out:
# enter a year: 2026
# its not a leap year

# %%
# to check whether entered date is in valid format and print increamented date
date = input("Enter the date in format dd/mm/yyyy: ")
dd, mm, yy = date.split('/')
dd = int(dd)
mm = int(mm)
yy = int(yy)
if mm == 1 or mm == 3 or mm == 5 or mm == 7 or mm == 8 or mm == 10 or mm == 12:
    max_days = 31
elif mm == 4 or mm == 6 or mm == 9 or mm == 11:
    max_days = 30
elif mm == 2:
    if (yy % 4 == 0 and yy % 100 != 0) or (yy % 400 == 0):
        max_days = 29
    else:
        max_days = 28
if dd < 1 or dd > max_days:
    print("Invalid date")
else:
    dd += 1
    if dd > max_days:
        dd = 1
        mm += 1

        if mm > 12:
            mm = 1
            yy += 1
    print("Incremented date is:", f"{dd:02d}/{mm:02d}/{yy}")
# Out:
# Enter the date in format dd/mm/yyyy: 21/03/2007
# Incremented date is: 22/03/2007

# %%
'''Problem: Calculate gross salary of an employee based on basic salary'''
basic=int(input("enter basic salary:"))
if basic <= 10000:
  print("HRA IS 20% AND DA IS 80%")
  gross_salary=(basic*20/100)+(basic*80/100)
  print("gross salary is:",gross_salary)

elif basic <= 20000:
  print("HRA IS 25% AND DA IS 90%")
  gross_salary1=(basic*25/100)+(basic*90/100)
  print("gross salary is:",gross_salary1)

else:
  print("HRA IS 30% AND DA IS 95%")
  gross_salary2=(basic*30/100)+(basic*95/100)
  print("gross salary is:",gross_salary2)
# Out:
# enter basic salary:25000
# HRA IS 30% AND DA IS 95%
# gross salary is: 31250.0

# %%
'''Problem: To calculate income tax based on annual income'''
income=float(input("enter annual income: "))
if income <=250000:
  print("no tax to be given")
elif income <=500000:
  print("tax to be given is 5%")
  tax=(income-250000)*(5/100)
  print("tax is:",tax)
elif income <=1000000:
  print("tax to be given is 20%")
  tax1=(income-250000)*(20/100)
  print("tax is:",tax2)
else:
  print("tax to be given is 30%")
  tax3=(income-250000)*(30/100)
  print("tax is:",tax3)
# Out:
# enter annual income: 500000
# tax to be given is 5%
# tax is: 12500.0
